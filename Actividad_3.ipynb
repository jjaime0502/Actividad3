# %% [markdown]
# <a href="https://colab.research.google.com/github/jjaime0502/Actividad3/blob/main/Actividad_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d6be30d4-ba2b-4e96-9850-63a902303642" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6be30d4-ba2b-4e96-9850-63a902303642">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('Ventas_totales_sin_nulos.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0                           65 non-null     int64
#  1   indice_tiempo                        65 non-null     object
#  2   ventas_precios_corrientes            65 non-null     float64
#  3   ventas_precios_constantes            65 non-null     float64
#  4   ventas_totales_canal_venta           65 non-null     float64
#  5   salon_ventas                         65 non-null     float64
#  6   canales_on_line                      65 non-null     float64
#  7   ventas_totales_medio_pago            65 non-null     float64
#  8   efectivo                             65 non-null     float64
#  9   tarjetas_debito                      65 non-null     float64
#  10  tarjetas_credito                     65 non-null     float64
# ...

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                             0
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# ...

# %%
valores_nulos=data.isnull().sum().sum()
valores_nulos
# Out:
# 0

# %%
data1=data.copy()
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0                           65 non-null     int64
#  1   indice_tiempo                        65 non-null     object
#  2   ventas_precios_corrientes            65 non-null     float64
#  3   ventas_precios_constantes            65 non-null     float64
#  4   ventas_totales_canal_venta           65 non-null     float64
#  5   salon_ventas                         65 non-null     float64
#  6   canales_on_line                      65 non-null     float64
#  7   ventas_totales_medio_pago            65 non-null     float64
#  8   efectivo                             65 non-null     float64
#  9   tarjetas_debito                      65 non-null     float64
#  10  tarjetas_credito                     65 non-null     float64
# ...

# %% [markdown]
# ##Columna Ventas Precios Corrientes

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data["ventas_precios_corrientes"])
plt.title("Outliers de ventas_precios_corrientes ")
plt.show() #Dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data1["ventas_precios_corrientes"]
Limite_Superior=y.mean() +2.5*y.std()
Limite_Inferior=y.mean() -2.5*y.std()
print("Límite superior permitido", Limite_Superior)
print("Límite inferior permitido", Limite_Inferior)
# Out:
# Límite superior permitido 190633.8863987013
# Límite inferior permitido -46153.48947562436

# %%
#Encontramos Outliers
outliers=data1[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 42          42    01/07/2020                   211140.7
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 42                    50791.4                 81140696.22   76413721.76
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 42      4726974.457                81140696.22  24935747.29      22143208.63
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 42  ...  23393038.41  2630487.791  9592798.115  8463266.123
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                     518942.5376
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 42                    11217153.19                          2502616.619
#
#     electronicos_articulos_hogar        otros
# 42                   6125265.839  5935993.913
#
# [1 rows x 25 columns]

# %%
#Ajustar máximo de filas
pd.options.display.max_rows=None

# %%
#Obtenemos datos limpios
data_clean_ventas_corrientes=data1[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean_ventas_corrientes
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# 5            5    01/06/2017                    29132.7
# 6            6    01/07/2017                    31182.3
# 7            7    01/08/2017                    31154.9
# 8            8    01/09/2017                    30521.5
# 9            9    01/10/2017                    32446.0
# 10          10    01/11/2017                    33629.0
# 11          11    01/12/2017                    40766.3
# 12          12    01/01/2018                    32479.2
# 13          13    01/02/2018                    31736.8
# 14          14    01/03/2018                    36531.3
# 15          15    01/04/2018                    34113.7
# ...

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(5, 3))
plt.boxplot(data_clean_ventas_corrientes["ventas_precios_corrientes"])
plt.title("ventas_precios_corrientes")
plt.show() #Dibujamos el diagrama

# %% [markdown]
# ## Ventas precios constantes

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data["ventas_precios_constantes"])
plt.title("Outliers de ventas_precios_constantes")
plt.show() #Dibujamos el diagrama

# %%
from numpy.lib.function_base import percentile
#Método aplicando Cuartiles. Encuentro cuartiles 0.25  0.75
y=data["ventas_precios_constantes"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 +1.5*iqr
Limite_Inferior_iqr=percentile25 -1.5*iqr
print("Límite superior permitido", Limite_Superior_iqr)
print("Límite inferior permitido", Limite_Inferior_iqr)
# Out:
# Límite superior permitido 31938.75
# Límite inferior permitido 18759.949999999997

# %%
outliers_iqr=data1[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 11          11    01/12/2017                    40766.3
# 42          42    01/07/2020                   211140.7
# 60          60    01/01/2022                   154517.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 11                    34084.5                4.076632e+07  4.032029e+07
# 42                    50791.4                8.114070e+07  7.641372e+07
# 60                    45463.4                1.545171e+08  1.496976e+08
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 11     4.460368e+05               4.076632e+07  13710305.37      11070098.74
# 42     4.726974e+06               8.114070e+07  24935747.29      22143208.63
# 60     4.819480e+06               1.545171e+08  46962602.22      46053650.13
#
#     ...       almacen    panaderia       lacteos        carnes  \
# 11  ...  9.667850e+06  1346130.813  3.684165e+06  3.674954e+06
# ...

# %%
#Obtenemos datos limpios
data_clean_ventas_constantes=data1[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_ventas_constantes
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# 5            5    01/06/2017                    29132.7
# 6            6    01/07/2017                    31182.3
# 7            7    01/08/2017                    31154.9
# 8            8    01/09/2017                    30521.5
# 9            9    01/10/2017                    32446.0
# 10          10    01/11/2017                    33629.0
# 12          12    01/01/2018                    32479.2
# 13          13    01/02/2018                    31736.8
# 14          14    01/03/2018                    36531.3
# 15          15    01/04/2018                    34113.7
# 16          16    01/05/2018                    35133.1
# ...

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data_clean_ventas_constantes["ventas_precios_constantes"])
plt.title("Outliers de ventas_constantes")
plt.show() #Dibujamos el diagrama

# %% [markdown]
# ## Salón ventas

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data["salon_ventas"])
plt.title("Outliers de salon_ventas")
plt.show() #Dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data1["salon_ventas"]
Limite_Superior=y.mean() +2.5*y.std()
Limite_Inferior=y.mean() -2.5*y.std()
print("Límite superior permitido", Limite_Superior)
print("Límite inferior permitido", Limite_Inferior)
# Out:
# Límite superior permitido 177311481.27046797
# Límite inferior permitido -25639308.449852586

# %%
#Encontramos Outliers
outliers=data1[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean_salon_ventas=data1[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean_salon_ventas
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# 5            5    01/06/2017                    29132.7
# 6            6    01/07/2017                    31182.3
# 7            7    01/08/2017                    31154.9
# 8            8    01/09/2017                    30521.5
# 9            9    01/10/2017                    32446.0
# 10          10    01/11/2017                    33629.0
# 11          11    01/12/2017                    40766.3
# 12          12    01/01/2018                    32479.2
# 13          13    01/02/2018                    31736.8
# 14          14    01/03/2018                    36531.3
# 15          15    01/04/2018                    34113.7
# ...

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data_clean_salon_ventas["salon_ventas"])
plt.title("Outliers de salon_ventas")
plt.show() #Dibujamos el diagrama

# %% [markdown]
# ## Tarjetas_debito

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data["tarjetas_debito"])
plt.title("Outliers de tarjetas_debito")
plt.show() #Dibujamos el diagrama

# %%
from numpy.lib.function_base import percentile
#Método aplicando Cuartiles. Encuentro cuartiles 0.25  0.75
y=data["tarjetas_debito"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 +1.5*iqr
Limite_Inferior_iqr=percentile25 -1.5*iqr
print("Límite superior permitido", Limite_Superior_iqr)
print("Límite inferior permitido", Limite_Inferior_iqr)
# Out:
# Límite superior permitido 51506999.8695
# Límite inferior permitido -16273799.862499997

# %%
outliers_iqr=data1[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean_tarjetas_debito=data1[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_tarjetas_debito
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# 5            5    01/06/2017                    29132.7
# 6            6    01/07/2017                    31182.3
# 7            7    01/08/2017                    31154.9
# 8            8    01/09/2017                    30521.5
# 9            9    01/10/2017                    32446.0
# 10          10    01/11/2017                    33629.0
# 11          11    01/12/2017                    40766.3
# 12          12    01/01/2018                    32479.2
# 13          13    01/02/2018                    31736.8
# 14          14    01/03/2018                    36531.3
# 15          15    01/04/2018                    34113.7
# ...

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data_clean_tarjetas_debito["tarjetas_debito"])
plt.title("Outliers de tarjetas_debito")
plt.show() #Dibujamos el diagrama

# %% [markdown]
# ## Tarjetas credito

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data["tarjetas_credito"])
plt.title("Outliers de tarjetas_credito")
plt.show() #Dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data1["tarjetas_credito"]
Limite_Superior=y.mean() +2.5*y.std()
Limite_Inferior=y.mean() -2.5*y.std()
print("Límite superior permitido", Limite_Superior)
print("Límite inferior permitido", Limite_Inferior)
# Out:
# Límite superior permitido 64708904.71662748
# Límite inferior permitido -10377514.028689023

# %%
outliers_iqr=data1[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 60                    45463.4                 154517094.2   149697614.6
# 61                    23802.1                 152202573.4   148406529.3
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
# ...

# %%
data_clean_tarjetas_credito=data1[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_tarjetas_credito
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# 5            5    01/06/2017                    29132.7
# 6            6    01/07/2017                    31182.3
# 7            7    01/08/2017                    31154.9
# 8            8    01/09/2017                    30521.5
# 9            9    01/10/2017                    32446.0
# 10          10    01/11/2017                    33629.0
# 11          11    01/12/2017                    40766.3
# 12          12    01/01/2018                    32479.2
# 13          13    01/02/2018                    31736.8
# 14          14    01/03/2018                    36531.3
# 15          15    01/04/2018                    34113.7
# ...

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data_clean_tarjetas_credito["tarjetas_credito"])
plt.title("Outliers de tarjetas_credito")
plt.show() #Dibujamos el diagrama

# %% [markdown]
# ## Bebidas

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data["bebidas"])
plt.title("Outliers de bebidas")
plt.show() #Dibujamos el diagrama

# %%
from numpy.lib.function_base import percentile
#Método aplicando Cuartiles. Encuentro cuartiles 0.25  0.75
y=data["bebidas"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 +1.5*iqr
Limite_Inferior_iqr=percentile25 -1.5*iqr
print("Límite superior permitido", Limite_Superior_iqr)
print("Límite inferior permitido", Limite_Inferior_iqr)
# Out:
# Límite superior permitido 22825184.4515
# Límite inferior permitido -6724636.7525

# %%
outliers_iqr=data1[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
data_clean_bebidas=data1[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_bebidas
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# 5            5    01/06/2017                    29132.7
# 6            6    01/07/2017                    31182.3
# 7            7    01/08/2017                    31154.9
# 8            8    01/09/2017                    30521.5
# 9            9    01/10/2017                    32446.0
# 10          10    01/11/2017                    33629.0
# 11          11    01/12/2017                    40766.3
# 12          12    01/01/2018                    32479.2
# 13          13    01/02/2018                    31736.8
# 14          14    01/03/2018                    36531.3
# 15          15    01/04/2018                    34113.7
# ...

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data_clean_bebidas["bebidas"])
plt.title("Outliers de bebidas")
plt.show() #Dibujamos el diagrama

# %% [markdown]
# ## carnes

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data["carnes"])
plt.title("Outliers de carnes")
plt.show() #Dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data1["carnes"]
Limite_Superior=y.mean() +2.5*y.std()
Limite_Inferior=y.mean() -2.5*y.std()
print("Límite superior permitido", Limite_Superior)
print("Límite inferior permitido", Limite_Inferior)
# Out:
# Límite superior permitido 22473743.696594283
# Límite inferior permitido -5620766.160686592

# %%
outliers_iqr=data1[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 63      4144283.743                177148082.8  53189998.68      50063972.79
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 63  ...  49991675.91  6746166.557  19309461.59  22877841.24
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 63          6510665.781                     1719458.547
# ...

# %%
data_clean_carnes=data1[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_carnes
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# 5            5    01/06/2017                    29132.7
# 6            6    01/07/2017                    31182.3
# 7            7    01/08/2017                    31154.9
# 8            8    01/09/2017                    30521.5
# 9            9    01/10/2017                    32446.0
# 10          10    01/11/2017                    33629.0
# 11          11    01/12/2017                    40766.3
# 12          12    01/01/2018                    32479.2
# 13          13    01/02/2018                    31736.8
# 14          14    01/03/2018                    36531.3
# 15          15    01/04/2018                    34113.7
# ...

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data_clean_carnes["carnes"])
plt.title("Outliers de carnes")
plt.show() #Dibujamos el diagrama

# %% [markdown]
# ## alimentos_preparados_rotiseria

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data["alimentos_preparados_rotiseria"])
plt.title("Outliers de alimentos_preparados_rotiseria")
plt.show() #Dibujamos el diagrama

# %%
from numpy.lib.function_base import percentile
#Método aplicando Cuartiles. Encuentro cuartiles 0.25  0.75
y=data["alimentos_preparados_rotiseria"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 +1.5*iqr
Limite_Inferior_iqr=percentile25 -1.5*iqr
print("Límite superior permitido", Limite_Superior_iqr)
print("Límite inferior permitido", Limite_Inferior_iqr)
# Out:
# Límite superior permitido 1546751.13875
# Límite inferior permitido -227313.79444999993

# %%
outliers_iqr=data1[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 62                    24612.4                 168982502.3   164321107.3
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59     5.116431e+06                183983151.9  56640033.15      55432191.37
# 62     4.661350e+05                168982502.3  51262080.99      47364363.88
# 63     4.144284e+06                177148082.8  53189998.68      50063972.79
# ...

# %%
data_clean_alimentos_rostiseria=data1[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_alimentos_rostiseria
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# 5            5    01/06/2017                    29132.7
# 6            6    01/07/2017                    31182.3
# 7            7    01/08/2017                    31154.9
# 8            8    01/09/2017                    30521.5
# 9            9    01/10/2017                    32446.0
# 10          10    01/11/2017                    33629.0
# 11          11    01/12/2017                    40766.3
# 12          12    01/01/2018                    32479.2
# 13          13    01/02/2018                    31736.8
# 14          14    01/03/2018                    36531.3
# 15          15    01/04/2018                    34113.7
# ...

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data_clean_alimentos_rostiseria["alimentos_preparados_rotiseria"])
plt.title("Outliers de alimentos_preparados_rotiseria")
plt.show() #Dibujamos el diagrama

# %% [markdown]
# ##indumentaria_calzado_textiles_hogar

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data["indumentaria_calzado_textiles_hogar"])
plt.title("Outliers de indumentaria_calzado_textiles_hogar")
plt.show() #Dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data1["indumentaria_calzado_textiles_hogar"]
Limite_Superior=y.mean() +2.5*y.std()
Limite_Inferior=y.mean() -2.5*y.std()
print("Límite superior permitido", Limite_Superior)
print("Límite inferior permitido", Limite_Inferior)
# Out:
# Límite superior permitido 4588372.68358407
# Límite inferior permitido -1032515.3739963772

# %%
outliers_iqr=data1[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 23          23    01/12/2018                    57204.0
# 29          29    01/06/2019                    54413.4
# 30          30    01/07/2019                    55044.5
# 34          34    01/11/2019                    67943.7
# 35          35    01/12/2019                    83524.6
# 36          36    01/01/2020                    70145.0
# 37          37    01/02/2020                    72494.4
# 40          40    01/05/2020                    78594.5
# 41          41    01/06/2020                    78232.9
# 42          42    01/07/2020                   211140.7
# 43          43    01/08/2020                    80412.0
# 44          44    01/09/2020                    77055.8
# 45          45    01/10/2020                    89224.3
# 46          46    01/11/2020                      200.5
# 47          47    01/12/2020                   115806.1
# 48          48    01/01/2021                    98007.6
# ...

# %%
data_clean_calzado_hogar=data1[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_calzado_hogar
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# 5            5    01/06/2017                    29132.7
# 6            6    01/07/2017                    31182.3
# 7            7    01/08/2017                    31154.9
# 8            8    01/09/2017                    30521.5
# 9            9    01/10/2017                    32446.0
# 10          10    01/11/2017                    33629.0
# 11          11    01/12/2017                    40766.3
# 12          12    01/01/2018                    32479.2
# 13          13    01/02/2018                    31736.8
# 14          14    01/03/2018                    36531.3
# 15          15    01/04/2018                    34113.7
# ...

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data_clean_calzado_hogar["indumentaria_calzado_textiles_hogar"])
plt.title("Outliers de indumentaria_calzado_textiles_hogar")
plt.show() #Dibujamos el diagrama

# %% [markdown]
# ## Otros

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data["otros"])
plt.title("Outliers de otros")
plt.show() #Dibujamos el diagrama

# %%
from numpy.lib.function_base import percentile
#Método aplicando Cuartiles. Encuentro cuartiles 0.25  0.75
y=data["otros"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 +1.5*iqr
Limite_Inferior_iqr=percentile25 -1.5*iqr
print("Límite superior permitido", Limite_Superior_iqr)
print("Límite inferior permitido", Limite_Inferior_iqr)
# Out:
# Límite superior permitido 13169100.024999999
# Límite inferior permitido -2599893.999

# %%
outliers_iqr=data1[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 60                    45463.4                 154517094.2   149697614.6
# 61                    23802.1                 152202573.4   148406529.3
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
# 60      4819479.554                154517094.2  46962602.22      46053650.13
# 61      3796044.076                152202573.4  46290956.21      45283575.25
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
# ...

# %%
data_clean_otros=data1[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_otros
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# 5            5    01/06/2017                    29132.7
# 6            6    01/07/2017                    31182.3
# 7            7    01/08/2017                    31154.9
# 8            8    01/09/2017                    30521.5
# 9            9    01/10/2017                    32446.0
# 10          10    01/11/2017                    33629.0
# 11          11    01/12/2017                    40766.3
# 12          12    01/01/2018                    32479.2
# 13          13    01/02/2018                    31736.8
# 14          14    01/03/2018                    36531.3
# 15          15    01/04/2018                    34113.7
# ...

# %%
#Realizamos diagrama de caja o bigote
fig=plt.figure(figsize=(10, 6))
plt.boxplot(data_clean_otros["otros"])
plt.title("Outliers de otros")
plt.show() #Dibujamos el diagrama

# %%
data_clean_ventas_corrientes.to_csv("Dataclean_Ventas_corrientes.csv")
data_clean_ventas_constantes.to_csv("Dataclean_Ventas_constantes.csv")
data_clean_salon_ventas.to_csv("Dataclean_salon_ventas.csv")
data_clean_tarjetas_debito.to_csv("Dataclean_tarjetas_debito.csv")
data_clean_tarjetas_credito.to_csv("Dataclean_tarjetas_credito.csv")
data_clean_bebidas.to_csv("Dataclean_bebidas.csv")
data_clean_bebidas.to_csv("Dataclean_carnes.csv")
data_clean_alimentos_rostiseria.to_csv("Dataclean_alimentos_preparados_rotiseria.csv")
data_clean_calzado_hogar.to_csv("Dataclean_indumentaria_calzado_textiles_hogar.csv")
data_clean_otros.to_csv("Dataclean_otros.csv")

# %%
#Descargar archivo
from google.colab import files

files.download("Dataclean_Ventas_corrientes.csv")
files.download("Dataclean_Ventas_constantes.csv")
files.download("Dataclean_salon_ventas.csv")
files.download("Dataclean_tarjetas_debito.csv")
files.download("Dataclean_tarjetas_credito.csv")
files.download("Dataclean_bebidas.csv")
files.download("Dataclean_carnes.csv")
files.download("Dataclean_alimentos_preparados_rotiseria.csv")
files.download("Dataclean_indumentaria_calzado_textiles_hogar.csv")
files.download("Dataclean_otros.csv")
